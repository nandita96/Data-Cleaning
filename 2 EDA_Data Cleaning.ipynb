# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
>>> import pandas as pd
>>> import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/drive/MyDrive/Case study/Cleaning2/Data.xlsx')

# Display the first 5 rows of the dataframe
df.head(2)
# Out:
#   UserLanguage  Country             Function Function_8_TEXT EDT  \
# 0           EN  Germany  Corporate functions             NaN  No
# 1           DE  Germany  Corporate functions             NaN  No
#
#                       Leadership Field Applicable  Collab tools_1  \
# 0  Yes, I am part of the Top 100   NaN        NaN             NaN
# 1  Yes, I am part of the Top 100   NaN        NaN             NaN
#
#    Collab tools_2  ...  No participation_5  No participation_6  \
# 0             NaN  ...                 NaN                 NaN
# 1             NaN  ...                 NaN                 NaN
#
#    No participation_7  No participation_8  Thoughts on learning  Q35     Q25  \
# 0                 NaN                 NaN                   NaN  NaN  Female
# 1                 NaN                 NaN                   NaN  NaN    Male
#
#        Q26           Q27  Q54
# 0  41 - 50  5 - 10 years  NaN
# 1     50 +   1 - 5 years  NaN
#
# [2 rows x 135 columns]

# %%
print(df.shape)    # record 11035  & column 135
print(df.info())    # float 74     &  object 61
# Out:
# (11035, 135)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11035 entries, 0 to 11034
# Columns: 135 entries, UserLanguage to Q54
# dtypes: float64(74), object(61)
# memory usage: 11.4+ MB
# None

# %%
pd.set_option('display.max_rows', 500)
df.dtypes
# Out:
# UserLanguage              object
# Country                   object
# Function                  object
# Function_8_TEXT           object
# EDT                       object
# Leadership                object
# Field                     object
# Applicable                object
# Collab tools_1           float64
# Collab tools_2           float64
# Collab tools_3           float64
# Agile_1                  float64
# Agile_2                  float64
# Agile_3                  float64
# Trends_1                 float64
# Trends_2                 float64
# Trends_3                 float64
# Trends_4                 float64
# Trends_5                 float64
# Trends_6                 float64
# Mindset & culture_1      float64
# Mindset & culture_2      float64
# Mindset & culture_3      float64
# Other thoughts            object
# Trends_1.1               float64
# Trends_2.1               float64
# Trends_3.1               float64
# Trends_4.1               float64
# Trends_5.1               float64
# Trends_6.1               float64
# Culture & mindset_1      float64
# Culture & mindset_2      float64
# Culture & mindset_3      float64
# Agile_1.1                float64
# Agile_2.1                float64
# Agile_3.1                float64
# Collab tools_1.1         float64
# Collab tools_2.1         float64
# Collab tools_3.1         float64
# Leadership_1              object
# Leadership_2              object
# Other thoughts.1          object
# Specialist leaders        object
# Specialist role           object
# Q27_1                    float64
# Q27_2                    float64
# Q27_3                    float64
# Q27_4                    float64
# Q27_5                    float64
# Q27_6                    float64
# Q27_7                    float64
# Q27_8                    float64
# Q27_9                    float64
# Q46                       object
# Q72_1                    float64
# Q72_2                    float64
# Q72_3                    float64
# Q72_4                    float64
# Q72_5                    float64
# Q73                       object
# Q30_1                    float64
# Q30_2                    float64
# Q30_3                    float64
# Q30_4                    float64
# Q30_5                    float64
# Q47                       object
# Q75_1                    float64
# Q75_2                    float64
# Q75_3                    float64
# Q76                       object
# Q78_1                    float64
# Q78_2                    float64
# Q78_3                    float64
# Q78_4                    float64
# Q78_5                    float64
# Q78_6                    float64
# Q78_7                    float64
# Q78_8                    float64
# Q79                       object
# Q81_1                    float64
# Q81_2                    float64
# Q82                       object
# Q84_1                    float64
# Q84_2                    float64
# Q84_3                    float64
# Q84_4                    float64
# Q85                       object
# Q87_1                    float64
# Q87_2                    float64
# Q87_3                    float64
# Q87_4                    float64
# Q87_5                    float64
# Q87_6                    float64
# Q88                       object
# Participation yes/no      object
# Evaluation_1              object
# Evaluation_2              object
# Evaluation_3              object
# Evaluation_4              object
# Evaluation_5              object
# Evaluation_6              object
# Evaluation_7              object
# Evaluation_8              object
# Evaluation_9              object
# Evaluation_10             object
# Preferences               object
# Preferences_8_TEXT        object
# Awareness                 object
# Awareness_4_TEXT          object
# Participation             object
# Participation_5_TEXT      object
# Recommendation_1         float64
# Recommendation_2          object
# Recommendation_3          object
# Recommendation_4          object
# Recommendation_5          object
# Recommendation_6          object
# Recommendation_7          object
# Recommendation_8          object
# Recommendation_8_TEXT     object
# Recommendation_9         float64
# No participation_1        object
# No participation_2        object
# No participation_3        object
# No participation_4        object
# No participation_5        object
# No participation_6        object
# No participation_7        object
# No participation_8        object
# Thoughts on learning      object
# Q35                       object
# Q25                       object
# Q26                       object
# Q27                       object
# Q54                       object
# dtype: object

# %%
percent_missing = df.isnull().sum()/(len(df))*100
percent_missing.sort_values(ascending=False)
# Out:
# Recommendation_9         100.000000
# Recommendation_1         100.000000
# Q79                       99.682827
# Q73                       99.673765
# Q82                       99.655641
# Q46                       99.619393
# Q88                       99.610331
# Q85                       99.565020
# Q76                       99.465338
# Preferences_8_TEXT        99.356593
# Recommendation_4          99.311282
# Other thoughts.1          99.211599
# Recommendation_5          99.139103
# Recommendation_6          99.048482
# Q47                       99.012234
# Recommendation_7          98.495696
# Recommendation_8_TEXT     97.924785
# Q27_9                     97.109198
# Q84_2                     96.973267
# Q27_7                     96.909832
# Q27_8                     96.891708
# Q27_6                     96.891708
# Q27_5                     96.882646
# Specialist leaders        96.864522
# Q84_4                     96.828274
# Q27_3                     96.764839
# Q84_1                     96.728591
# Q27_2                     96.701405
# Q27_4                     96.683280
# Q27_1                     96.628908
# Q84_3                     96.574536
# Q78_4                     96.067059
# Q78_3                     96.012687
# Q78_2                     95.994563
# Q78_6                     95.967377
# Q78_1                     95.885818
# Q78_7                     95.840507
# Q78_8                     95.768011
# Agile_3.1                 95.749887
# Collab tools_3.1          95.604894
# Leadership_2              95.604894
# Leadership_1              95.595831
# Collab tools_2.1          95.577707
# Collab tools_1.1          95.568645
# Agile_2.1                 95.559583
# Culture & mindset_3       95.550521
# Agile_1.1                 95.541459
# Trends_6.1                95.505211
# Culture & mindset_2       95.487087
# Culture & mindset_1       95.487087
# Q54                       95.459900
# Trends_4.1                95.441776
# Trends_2.1                95.441776
# Trends_3.1                95.414590
# Trends_1.1                95.387404
# Trends_5.1                95.360217
# Q78_5                     95.314907
# Q81_1                     95.215224
# Q81_2                     95.197100
# Q87_4                     95.006797
# Q87_5                     95.006797
# Q87_6                     94.961486
# Participation_5_TEXT      94.879928
# Q72_5                     94.653376
# Q72_3                     94.544631
# Q72_2                     94.463072
# Q87_3                     94.435886
# Q72_4                     94.399638
# Q72_1                     94.245582
# Q87_2                     93.638423
# Q87_1                     93.602175
# Awareness_4_TEXT          93.502492
# Q75_3                     93.294064
# Q75_2                     92.786588
# Q75_1                     92.215677
# Thoughts on learning      91.807884
# Recommendation_2          91.255097
# Recommendation_3          91.155415
# No participation_6        90.593566
# No participation_8        90.403262
# No participation_4        89.886724
# Other thoughts            89.777979
# Q30_4                     89.460807
# No participation_5        89.397372
# No participation_3        89.324875
# Q30_3                     88.826461
# No participation_2        88.599909
# Q30_5                     88.309923
# No participation_7        87.748074
# Q30_2                     87.612143
# Q30_1                     87.612143
# Function_8_TEXT           87.403715
# Recommendation_8          87.376529
# No participation_1        86.696874
# EDT                       77.752605
# Participation             72.985954
# Q35                       72.469415
# Trends_6                  68.572723
# Trends_2                  67.947440
# Trends_1                  66.696874
# Trends_4                  66.388763
# Trends_3                  66.144087
# Trends_5                  63.851382
# Awareness                 63.017671
# Agile_3                   56.221115
# Agile_2                   50.711373
# Agile_1                   49.306751
# Evaluation_7              48.164930
# Evaluation_5              47.050295
# Evaluation_6              45.944721
# Evaluation_9              45.410059
# Evaluation_10             44.766652
# Evaluation_3              44.549162
# Evaluation_2              44.431355
# Evaluation_4              44.286362
# Evaluation_8              43.960127
# Evaluation_1              43.488899
# Preferences               42.564567
# Mindset & culture_3       33.855913
# Mindset & culture_2       31.826008
# Collab tools_3            31.554146
# Mindset & culture_1       30.475759
# Field                     30.348890
# Q25                       28.735841
# Q26                       28.735841
# Q27                       28.735841
# Participation yes/no      25.826914
# Specialist role           25.491618
# Collab tools_2            21.939284
# Collab tools_1            18.695061
# Applicable                10.457635
# Leadership                 3.815134
# Function                   3.180788
# Country                    1.658360
# UserLanguage               0.000000
# dtype: float64

# %%
percent_missing_above_89 = percent_missing[percent_missing > 89]
percent_missing_above_89.sort_values(ascending=False).count()
# Out:
# 85

# %%
df.info(verbose=True, show_counts=True)  # use verbose and show_count to have column, non-null count, dtype values or it will just give you short summary with no deatil info.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11035 entries, 0 to 11034
# Data columns (total 135 columns):
#  #    Column                 Non-Null Count  Dtype
# ---   ------                 --------------  -----
#  0    UserLanguage           11035 non-null  object
#  1    Country                10852 non-null  object
#  2    Function               10684 non-null  object
#  3    Function_8_TEXT        1390 non-null   object
#  4    EDT                    2455 non-null   object
#  5    Leadership             10614 non-null  object
#  6    Field                  7686 non-null   object
#  7    Applicable             9881 non-null   object
#  8    Collab tools_1         8972 non-null   float64
#  9    Collab tools_2         8614 non-null   float64
#  10   Collab tools_3         7553 non-null   float64
#  11   Agile_1                5594 non-null   float64
#  12   Agile_2                5439 non-null   float64
#  13   Agile_3                4831 non-null   float64
#  14   Trends_1               3675 non-null   float64
#  15   Trends_2               3537 non-null   float64
#  16   Trends_3               3736 non-null   float64
#  17   Trends_4               3709 non-null   float64
#  18   Trends_5               3989 non-null   float64
#  19   Trends_6               3468 non-null   float64
#  20   Mindset & culture_1    7672 non-null   float64
#  21   Mindset & culture_2    7523 non-null   float64
#  22   Mindset & culture_3    7299 non-null   float64
#  23   Other thoughts         1128 non-null   object
#  24   Trends_1.1             509 non-null    float64
#  25   Trends_2.1             503 non-null    float64
#  26   Trends_3.1             506 non-null    float64
#  27   Trends_4.1             503 non-null    float64
#  28   Trends_5.1             512 non-null    float64
#  29   Trends_6.1             496 non-null    float64
#  30   Culture & mindset_1    498 non-null    float64
#  31   Culture & mindset_2    498 non-null    float64
#  32   Culture & mindset_3    491 non-null    float64
#  33   Agile_1.1              492 non-null    float64
#  34   Agile_2.1              490 non-null    float64
#  35   Agile_3.1              469 non-null    float64
#  36   Collab tools_1.1       489 non-null    float64
#  37   Collab tools_2.1       488 non-null    float64
#  38   Collab tools_3.1       485 non-null    float64
#  39   Leadership_1           486 non-null    object
#  40   Leadership_2           485 non-null    object
#  41   Other thoughts.1       87 non-null     object
#  42   Specialist leaders     346 non-null    object
#  43   Specialist role        8222 non-null   object
#  44   Q27_1                  372 non-null    float64
#  45   Q27_2                  364 non-null    float64
#  46   Q27_3                  357 non-null    float64
#  47   Q27_4                  366 non-null    float64
#  48   Q27_5                  344 non-null    float64
#  49   Q27_6                  343 non-null    float64
#  50   Q27_7                  341 non-null    float64
#  51   Q27_8                  343 non-null    float64
#  52   Q27_9                  319 non-null    float64
#  53   Q46                    42 non-null     object
#  54   Q72_1                  635 non-null    float64
#  55   Q72_2                  611 non-null    float64
#  56   Q72_3                  602 non-null    float64
#  57   Q72_4                  618 non-null    float64
#  58   Q72_5                  590 non-null    float64
#  59   Q73                    36 non-null     object
#  60   Q30_1                  1367 non-null   float64
#  61   Q30_2                  1367 non-null   float64
#  62   Q30_3                  1233 non-null   float64
#  63   Q30_4                  1163 non-null   float64
#  64   Q30_5                  1290 non-null   float64
#  65   Q47                    109 non-null    object
#  66   Q75_1                  859 non-null    float64
#  67   Q75_2                  796 non-null    float64
#  68   Q75_3                  740 non-null    float64
#  69   Q76                    59 non-null     object
#  70   Q78_1                  454 non-null    float64
#  71   Q78_2                  442 non-null    float64
#  72   Q78_3                  440 non-null    float64
#  73   Q78_4                  434 non-null    float64
#  74   Q78_5                  517 non-null    float64
#  75   Q78_6                  445 non-null    float64
#  76   Q78_7                  459 non-null    float64
#  77   Q78_8                  467 non-null    float64
#  78   Q79                    35 non-null     object
#  79   Q81_1                  528 non-null    float64
#  80   Q81_2                  530 non-null    float64
#  81   Q82                    38 non-null     object
#  82   Q84_1                  361 non-null    float64
#  83   Q84_2                  334 non-null    float64
#  84   Q84_3                  378 non-null    float64
#  85   Q84_4                  350 non-null    float64
#  86   Q85                    48 non-null     object
#  87   Q87_1                  706 non-null    float64
#  88   Q87_2                  702 non-null    float64
#  89   Q87_3                  614 non-null    float64
#  90   Q87_4                  551 non-null    float64
#  91   Q87_5                  551 non-null    float64
#  92   Q87_6                  556 non-null    float64
#  93   Q88                    43 non-null     object
#  94   Participation yes/no   8185 non-null   object
#  95   Evaluation_1           6236 non-null   object
#  96   Evaluation_2           6132 non-null   object
#  97   Evaluation_3           6119 non-null   object
#  98   Evaluation_4           6148 non-null   object
#  99   Evaluation_5           5843 non-null   object
#  100  Evaluation_6           5965 non-null   object
#  101  Evaluation_7           5720 non-null   object
#  102  Evaluation_8           6184 non-null   object
#  103  Evaluation_9           6024 non-null   object
#  104  Evaluation_10          6095 non-null   object
#  105  Preferences            6338 non-null   object
#  106  Preferences_8_TEXT     71 non-null     object
#  107  Awareness              4081 non-null   object
#  108  Awareness_4_TEXT       717 non-null    object
#  109  Participation          2981 non-null   object
#  110  Participation_5_TEXT   565 non-null    object
#  111  Recommendation_1       0 non-null      float64
#  112  Recommendation_2       965 non-null    object
#  113  Recommendation_3       976 non-null    object
#  114  Recommendation_4       76 non-null     object
#  115  Recommendation_5       95 non-null     object
#  116  Recommendation_6       105 non-null    object
#  117  Recommendation_7       166 non-null    object
#  118  Recommendation_8       1393 non-null   object
#  119  Recommendation_8_TEXT  229 non-null    object
#  120  Recommendation_9       0 non-null      float64
#  121  No participation_1     1468 non-null   object
#  122  No participation_2     1258 non-null   object
#  123  No participation_3     1178 non-null   object
#  124  No participation_4     1116 non-null   object
#  125  No participation_5     1170 non-null   object
#  126  No participation_6     1038 non-null   object
#  127  No participation_7     1352 non-null   object
#  128  No participation_8     1059 non-null   object
#  129  Thoughts on learning   904 non-null    object
#  130  Q35                    3038 non-null   object
#  131  Q25                    7864 non-null   object
#  132  Q26                    7864 non-null   object
#  133  Q27                    7864 non-null   object
#  134  Q54                    501 non-null    object
# dtypes: float64(74), object(61)
# memory usage: 11.4+ MB

# %% [markdown]
# 1.   Dropped : 799 duplicate Row
# 2.
# 4.   Delete column if missing value > 89.97%
# 5.   Droped 81 Column
# 6.   Selected 55 column

# %%
df2=df

# %%
# Check columns before dropping
print("Before dropping:", len(df.columns))

# Drop columns    # drop maybe later 'No participation_6',	'No participation_8',	'No participation_4'
# 2ns drop two more column 'Function_8_TEXT, 'Leadership_1' , 'Leadership_2'
df2 = df2.drop(columns=[ 'Recommendation_1','Recommendation_9','Q79','Q73','Q82','Q46','Q88','Q85','Q76','Preferences_8_TEXT','Function_8_TEXT','Recommendation_4',
                       'Other thoughts.1','Recommendation_5',	'Recommendation_6',	'Q47',	'Recommendation_7',	'Recommendation_8_TEXT',	'Q27_9',
                        'Q84_2',	'Q27_7',	'Q27_6',	'Q27_8',	'Q27_5',	'Specialist leaders',	'Q84_4',	'Q27_3',	'Q84_1',	'Q27_2',	'Q27_4',
                        'Q27_1',	'Q84_3',	'Q78_4',	'Q78_3',	'Q78_2',	'Q78_6',	'Q78_1',	'Q78_7',	'Q78_8',	'Agile_3.1',	'Collab tools_3.1',
                        'Collab tools_2.1',	'Collab tools_1.1',	'Agile_2.1',	'Culture & mindset_3',	'Agile_1.1',	'Trends_6.1',	'Culture & mindset_1',
                        'Culture & mindset_2',	'Q54',	'Trends_2.1',	'Trends_4.1',	'Trends_3.1',	'Trends_1.1',	'Trends_5.1',	'Q78_5',	'Q81_1',	'Q81_2',
                        'Q87_4',	'Q87_5',	'Q87_6',	'Participation_5_TEXT',	'Q72_5',	'Q72_3',	'Q72_2',	'Q87_3',	'Q72_4',	'Q72_1',	'Q87_2',	'Q87_1',
                        'Awareness_4_TEXT',	'Q75_3',	'Q75_2',	'Q75_1',	'Thoughts on learning',	'Recommendation_2',	'Recommendation_3',	'Other thoughts',
                        'Leadership_1', 'Leadership_2'])

# Check columns after dropping
print("After dropping:", len(df2.columns))
# Out:
# Before dropping: 135
# After dropping: 55

# %%
df2.duplicated().sum()
# Out:
# 919

# %%
df2= df2.drop_duplicates()
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Now we will delete records where 'Function', 'Country', ' UserLanguage', 'Leadership'

# %%
df2.info()    # 10116 entries, 0 to 11033
              # Data columns (total 55 columns):
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10116 entries, 0 to 11033
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserLanguage          10116 non-null  object
#  1   Country               10105 non-null  object
#  2   Function              10087 non-null  object
#  3   EDT                   2339 non-null   object
#  4   Leadership            10054 non-null  object
#  5   Field                 7324 non-null   object
#  6   Applicable            9493 non-null   object
#  7   Collab tools_1        8940 non-null   float64
#  8   Collab tools_2        8585 non-null   float64
#  9   Collab tools_3        7527 non-null   float64
#  10  Agile_1               5593 non-null   float64
#  11  Agile_2               5438 non-null   float64
#  12  Agile_3               4830 non-null   float64
#  13  Trends_1              3675 non-null   float64
#  14  Trends_2              3537 non-null   float64
#  15  Trends_3              3736 non-null   float64
#  16  Trends_4              3709 non-null   float64
#  17  Trends_5              3989 non-null   float64
#  18  Trends_6              3468 non-null   float64
#  19  Mindset & culture_1   7672 non-null   float64
#  20  Mindset & culture_2   7523 non-null   float64
#  21  Mindset & culture_3   7299 non-null   float64
#  22  Specialist role       8222 non-null   object
#  23  Q30_1                 1367 non-null   float64
#  24  Q30_2                 1367 non-null   float64
#  25  Q30_3                 1233 non-null   float64
#  26  Q30_4                 1163 non-null   float64
#  27  Q30_5                 1290 non-null   float64
#  28  Participation yes/no  8183 non-null   object
#  29  Evaluation_1          6236 non-null   object
#  30  Evaluation_2          6132 non-null   object
#  31  Evaluation_3          6119 non-null   object
#  32  Evaluation_4          6148 non-null   object
#  33  Evaluation_5          5843 non-null   object
#  34  Evaluation_6          5965 non-null   object
#  35  Evaluation_7          5720 non-null   object
#  36  Evaluation_8          6184 non-null   object
#  37  Evaluation_9          6024 non-null   object
#  38  Evaluation_10         6095 non-null   object
#  39  Preferences           6338 non-null   object
#  40  Awareness             4081 non-null   object
#  41  Participation         2981 non-null   object
#  42  Recommendation_8      1393 non-null   object
#  43  No participation_1    1468 non-null   object
#  44  No participation_2    1258 non-null   object
#  45  No participation_3    1178 non-null   object
#  46  No participation_4    1116 non-null   object
#  47  No participation_5    1170 non-null   object
#  48  No participation_6    1038 non-null   object
#  49  No participation_7    1352 non-null   object
#  50  No participation_8    1059 non-null   object
#  51  Q35                   3038 non-null   object
#  52  Q25                   7864 non-null   object
#  53  Q26                   7864 non-null   object
#  54  Q27                   7864 non-null   object
# dtypes: float64(20), object(35)
# memory usage: 4.3+ MB

# %%
df2.isna().sum().head()
# Out:
# UserLanguage       0
# Country           11
# Function          29
# EDT             7777
# Leadership        62
# dtype: int64

# %%
# 10054 entries, 0 to 11033
# Data columns (total 55 columns)

df3 = df2.dropna(subset=['Function', 'Country', 'UserLanguage', 'Leadership'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10054 entries, 0 to 11033
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserLanguage          10054 non-null  object
#  1   Country               10054 non-null  object
#  2   Function              10054 non-null  object
#  3   EDT                   2331 non-null   object
#  4   Leadership            10054 non-null  object
#  5   Field                 7324 non-null   object
#  6   Applicable            9493 non-null   object
#  7   Collab tools_1        8940 non-null   float64
#  8   Collab tools_2        8585 non-null   float64
#  9   Collab tools_3        7527 non-null   float64
#  10  Agile_1               5593 non-null   float64
#  11  Agile_2               5438 non-null   float64
#  12  Agile_3               4830 non-null   float64
#  13  Trends_1              3675 non-null   float64
#  14  Trends_2              3537 non-null   float64
#  15  Trends_3              3736 non-null   float64
#  16  Trends_4              3709 non-null   float64
#  17  Trends_5              3989 non-null   float64
#  18  Trends_6              3468 non-null   float64
#  19  Mindset & culture_1   7672 non-null   float64
#  20  Mindset & culture_2   7523 non-null   float64
#  21  Mindset & culture_3   7299 non-null   float64
#  22  Specialist role       8222 non-null   object
#  23  Q30_1                 1367 non-null   float64
#  24  Q30_2                 1367 non-null   float64
#  25  Q30_3                 1233 non-null   float64
#  26  Q30_4                 1163 non-null   float64
#  27  Q30_5                 1290 non-null   float64
#  28  Participation yes/no  8183 non-null   object
#  29  Evaluation_1          6236 non-null   object
#  30  Evaluation_2          6132 non-null   object
#  31  Evaluation_3          6119 non-null   object
#  32  Evaluation_4          6148 non-null   object
#  33  Evaluation_5          5843 non-null   object
#  34  Evaluation_6          5965 non-null   object
#  35  Evaluation_7          5720 non-null   object
#  36  Evaluation_8          6184 non-null   object
#  37  Evaluation_9          6024 non-null   object
#  38  Evaluation_10         6095 non-null   object
#  39  Preferences           6338 non-null   object
#  40  Awareness             4081 non-null   object
#  41  Participation         2981 non-null   object
#  42  Recommendation_8      1393 non-null   object
#  43  No participation_1    1468 non-null   object
#  44  No participation_2    1258 non-null   object
#  45  No participation_3    1178 non-null   object
#  46  No participation_4    1116 non-null   object
#  47  No participation_5    1170 non-null   object
#  48  No participation_6    1038 non-null   object
#  49  No participation_7    1352 non-null   object
#  50  No participation_8    1059 non-null   object
#  51  Q35                   3038 non-null   object
#  52  Q25                   7864 non-null   object
#  53  Q26                   7864 non-null   object
#  54  Q27                   7864 non-null   object
# dtypes: float64(20), object(35)
# memory usage: 4.3+ MB

# %%
df3.select_dtypes(include=['float']).columns
# Out:
# Index(['Collab tools_1', 'Collab tools_2', 'Collab tools_3', 'Agile_1',
#        'Agile_2', 'Agile_3', 'Trends_1', 'Trends_2', 'Trends_3', 'Trends_4',
#        'Trends_5', 'Trends_6', 'Mindset & culture_1', 'Mindset & culture_2',
#        'Mindset & culture_3', 'Q30_1', 'Q30_2', 'Q30_3', 'Q30_4', 'Q30_5'],
#       dtype='object')

# %%
selected_columns = ['Collab tools_1', 'Collab tools_2', 'Collab tools_3', 'Agile_1',
       'Agile_2', 'Agile_3', 'Trends_1', 'Trends_2', 'Trends_3', 'Trends_4',
       'Trends_5', 'Trends_6', 'Mindset & culture_1', 'Mindset & culture_2',
       'Mindset & culture_3', 'Q30_1', 'Q30_2', 'Q30_3', 'Q30_4', 'Q30_5']

correlation_matrix = df3[selected_columns].corr()

plt.figure(figsize=(18, 12))
#mask = np.zeros_like(correlation_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', mask = mask)
   #OR
#sns.heatmap(correlation_matrix, vmax=1.0, vmin=0, center=0, annot=True,
            #square=False, linewidths=.01,cbar_kws={"shrink": 0.75}, cmap='coolwarm', mask = mask)

plt.show()

# %%
# @title Default title text
# No
# This code also be used of you are looking to have corr just for numeric variable

dataplot = sns.heatmap(df3.corr(numeric_only=True))
plt.figure(figsize=(18, 12))
plt.show()

# %% [markdown]
# * We have correlation between
#
#
# *   Q30_1 = Q30_2
# *   Aigile_3 = Agile_2
# *   Drop **'Q30_1','Agile_3', 'Trends_6', 'Trends_2', 'Trends_1', 'Trends_4', 'Trends_3', 'Mindset & culture_3','Mindset & culture_1',**
# *   Also drop **Agile_1**

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10054 entries, 0 to 11033
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserLanguage          10054 non-null  object
#  1   Country               10054 non-null  object
#  2   Function              10054 non-null  object
#  3   EDT                   2331 non-null   object
#  4   Leadership            10054 non-null  object
#  5   Field                 7324 non-null   object
#  6   Applicable            9493 non-null   object
#  7   Collab tools_1        8940 non-null   float64
#  8   Collab tools_2        8585 non-null   float64
#  9   Collab tools_3        7527 non-null   float64
#  10  Agile_1               5593 non-null   float64
#  11  Agile_2               5438 non-null   float64
#  12  Agile_3               4830 non-null   float64
#  13  Trends_1              3675 non-null   float64
#  14  Trends_2              3537 non-null   float64
#  15  Trends_3              3736 non-null   float64
#  16  Trends_4              3709 non-null   float64
#  17  Trends_5              3989 non-null   float64
#  18  Trends_6              3468 non-null   float64
#  19  Mindset & culture_1   7672 non-null   float64
#  20  Mindset & culture_2   7523 non-null   float64
#  21  Mindset & culture_3   7299 non-null   float64
#  22  Specialist role       8222 non-null   object
#  23  Q30_1                 1367 non-null   float64
#  24  Q30_2                 1367 non-null   float64
#  25  Q30_3                 1233 non-null   float64
#  26  Q30_4                 1163 non-null   float64
#  27  Q30_5                 1290 non-null   float64
#  28  Participation yes/no  8183 non-null   object
#  29  Evaluation_1          6236 non-null   object
#  30  Evaluation_2          6132 non-null   object
#  31  Evaluation_3          6119 non-null   object
#  32  Evaluation_4          6148 non-null   object
#  33  Evaluation_5          5843 non-null   object
#  34  Evaluation_6          5965 non-null   object
#  35  Evaluation_7          5720 non-null   object
#  36  Evaluation_8          6184 non-null   object
#  37  Evaluation_9          6024 non-null   object
#  38  Evaluation_10         6095 non-null   object
#  39  Preferences           6338 non-null   object
#  40  Awareness             4081 non-null   object
#  41  Participation         2981 non-null   object
#  42  Recommendation_8      1393 non-null   object
#  43  No participation_1    1468 non-null   object
#  44  No participation_2    1258 non-null   object
#  45  No participation_3    1178 non-null   object
#  46  No participation_4    1116 non-null   object
#  47  No participation_5    1170 non-null   object
#  48  No participation_6    1038 non-null   object
#  49  No participation_7    1352 non-null   object
#  50  No participation_8    1059 non-null   object
#  51  Q35                   3038 non-null   object
#  52  Q25                   7864 non-null   object
#  53  Q26                   7864 non-null   object
#  54  Q27                   7864 non-null   object
# dtypes: float64(20), object(35)
# memory usage: 4.3+ MB

# %%
df4 = df3.drop(columns=['Q30_1','Agile_3', 'Trends_6', 'Trends_2', 'Trends_1', 'Trends_4', 'Trends_3', 'Mindset & culture_3','Mindset & culture_1','Agile_1'])
df4.duplicated().sum()
# Out:
# 10

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10054 entries, 0 to 11033
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserLanguage          10054 non-null  object
#  1   Country               10054 non-null  object
#  2   Function              10054 non-null  object
#  3   EDT                   2331 non-null   object
#  4   Leadership            10054 non-null  object
#  5   Field                 7324 non-null   object
#  6   Applicable            9493 non-null   object
#  7   Collab tools_1        8940 non-null   float64
#  8   Collab tools_2        8585 non-null   float64
#  9   Collab tools_3        7527 non-null   float64
#  10  Agile_2               5438 non-null   float64
#  11  Trends_5              3989 non-null   float64
#  12  Mindset & culture_2   7523 non-null   float64
#  13  Specialist role       8222 non-null   object
#  14  Q30_2                 1367 non-null   float64
#  15  Q30_3                 1233 non-null   float64
#  16  Q30_4                 1163 non-null   float64
#  17  Q30_5                 1290 non-null   float64
#  18  Participation yes/no  8183 non-null   object
#  19  Evaluation_1          6236 non-null   object
#  20  Evaluation_2          6132 non-null   object
#  21  Evaluation_3          6119 non-null   object
#  22  Evaluation_4          6148 non-null   object
#  23  Evaluation_5          5843 non-null   object
#  24  Evaluation_6          5965 non-null   object
#  25  Evaluation_7          5720 non-null   object
#  26  Evaluation_8          6184 non-null   object
#  27  Evaluation_9          6024 non-null   object
#  28  Evaluation_10         6095 non-null   object
#  29  Preferences           6338 non-null   object
#  30  Awareness             4081 non-null   object
#  31  Participation         2981 non-null   object
#  32  Recommendation_8      1393 non-null   object
#  33  No participation_1    1468 non-null   object
#  34  No participation_2    1258 non-null   object
#  35  No participation_3    1178 non-null   object
#  36  No participation_4    1116 non-null   object
#  37  No participation_5    1170 non-null   object
#  38  No participation_6    1038 non-null   object
#  39  No participation_7    1352 non-null   object
#  40  No participation_8    1059 non-null   object
#  41  Q35                   3038 non-null   object
#  42  Q25                   7864 non-null   object
#  43  Q26                   7864 non-null   object
#  44  Q27                   7864 non-null   object
# dtypes: float64(10), object(35)
# memory usage: 3.5+ MB

# %%
df4.select_dtypes(include=['object']).columns
# Out:
# Index(['UserLanguage', 'Country', 'Function', 'EDT', 'Leadership', 'Field',
#        'Applicable', 'Specialist role', 'Participation yes/no', 'Evaluation_1',
#        'Evaluation_2', 'Evaluation_3', 'Evaluation_4', 'Evaluation_5',
#        'Evaluation_6', 'Evaluation_7', 'Evaluation_8', 'Evaluation_9',
#        'Evaluation_10', 'Preferences', 'Awareness', 'Participation',
#        'Recommendation_8', 'No participation_1', 'No participation_2',
#        'No participation_3', 'No participation_4', 'No participation_5',
#        'No participation_6', 'No participation_7', 'No participation_8', 'Q35',
#        'Q25', 'Q26', 'Q27'],
#       dtype='object')

# %%
#df4.to_csv('check_data2_5oct.csv')

# %%
df4.describe()
# Out:
#        Collab tools_1  Collab tools_2  Collab tools_3      Agile_2  \
# count     8940.000000     8585.000000     7527.000000  5438.000000
# mean         3.982215        3.029936        2.459944     3.129827
# std          0.999394        1.302433        1.352829     1.213493
# min          1.000000        1.000000        1.000000     1.000000
# 25%          3.000000        2.000000        1.000000     2.000000
# 50%          4.000000        3.000000        2.000000     3.000000
# 75%          5.000000        4.000000        4.000000     4.000000
# max          5.000000        5.000000        5.000000     5.000000
#
#           Trends_5  Mindset & culture_2        Q30_2        Q30_3  \
# count  3989.000000           7523.00000  1367.000000  1233.000000
# mean      3.842316              3.18902     3.542063     2.857259
# std       1.013675              1.24553     1.115356     1.250609
# min       1.000000              1.00000     1.000000     1.000000
# 25%       3.000000              2.00000     3.000000     2.000000
# 50%       4.000000              3.00000     4.000000     3.000000
# 75%       5.000000              4.00000     4.000000     4.000000
# max       5.000000              5.00000     5.000000     5.000000
#
#              Q30_4        Q30_5
# count  1163.000000  1290.000000
# mean      2.572657     3.089147
# std       1.356000     1.309614
# min       1.000000     1.000000
# 25%       1.000000     2.000000
# 50%       2.000000     3.000000
# 75%       4.000000     4.000000
# max       5.000000     5.000000

# %%
#df4['Collab tools_1'] = np.where((df4['Collab tools_1'] >= 3) & (df['Collab tools_1'] <=5), 'little developed', 'outstanding')
df4['Collab tools_1']=df4['Collab tools_1'].replace({2: 'little developed', 3 : 'little developed', 4 : 'outstanding', 5 :'outstanding'})
df4['Collab tools_1']

# %%
import numpy as np
import pandas as pd

# Define the function
def process_collab_tools(column):
    # Apply conditions and replace values accordingly
    #column = np.where((column >= 3) & (column <= 5), 'little developed', 'outstanding')
    # Replace specific values
    column = pd.Series(column).replace({2: 'little developed', 3: 'little developed', 4: 'outstanding', 5: 'outstanding'})
    return column

# Example usage with df4['Collab tools_1']
df4['Collab tools_1']=process_collab_tools(df4['Collab tools_1'])
df4['Collab tools_2']=process_collab_tools(df4['Collab tools_2'])
df4['Collab tools_3']=process_collab_tools(df4['Collab tools_3'])
df4['Agile_2']=process_collab_tools(df4['Agile_2'])
df4['Trends_5']=process_collab_tools(df4['Trends_5'])
df4['Mindset & culture_2']=process_collab_tools(df4['Mindset & culture_2'])
df4['Q30_2']=process_collab_tools(df4['Q30_2'])
df4['Q30_3']=process_collab_tools(df4['Q30_3'])
df4['Q30_4']=process_collab_tools(df4['Q30_4'])
df4['Q30_5']=process_collab_tools(df4['Q30_5'])

# %%
df4.to_csv('Eon_CleanData.csv')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10054 entries, 0 to 11033
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserLanguage          10054 non-null  object
#  1   Country               10054 non-null  object
#  2   Function              10054 non-null  object
#  3   EDT                   2331 non-null   object
#  4   Leadership            10054 non-null  object
#  5   Field                 7324 non-null   object
#  6   Applicable            9493 non-null   object
#  7   Collab tools_1        8940 non-null   object
#  8   Collab tools_2        8585 non-null   object
#  9   Collab tools_3        7527 non-null   object
#  10  Agile_2               5438 non-null   object
#  11  Trends_5              3989 non-null   object
#  12  Mindset & culture_2   7523 non-null   object
#  13  Specialist role       8222 non-null   object
#  14  Q30_2                 1367 non-null   object
#  15  Q30_3                 1233 non-null   object
#  16  Q30_4                 1163 non-null   object
#  17  Q30_5                 1290 non-null   object
#  18  Participation yes/no  8183 non-null   object
#  19  Evaluation_1          6236 non-null   object
#  20  Evaluation_2          6132 non-null   object
#  21  Evaluation_3          6119 non-null   object
#  22  Evaluation_4          6148 non-null   object
#  23  Evaluation_5          5843 non-null   object
#  24  Evaluation_6          5965 non-null   object
#  25  Evaluation_7          5720 non-null   object
#  26  Evaluation_8          6184 non-null   object
#  27  Evaluation_9          6024 non-null   object
#  28  Evaluation_10         6095 non-null   object
#  29  Preferences           6338 non-null   object
#  30  Awareness             4081 non-null   object
#  31  Participation         2981 non-null   object
#  32  Recommendation_8      1393 non-null   object
#  33  No participation_1    1468 non-null   object
#  34  No participation_2    1258 non-null   object
#  35  No participation_3    1178 non-null   object
#  36  No participation_4    1116 non-null   object
#  37  No participation_5    1170 non-null   object
#  38  No participation_6    1038 non-null   object
#  39  No participation_7    1352 non-null   object
#  40  No participation_8    1059 non-null   object
#  41  Q35                   3038 non-null   object
#  42  Q25                   7864 non-null   object
#  43  Q26                   7864 non-null   object
#  44  Q27                   7864 non-null   object
# dtypes: object(45)
# memory usage: 3.5+ MB
